# %%
import pandas as pd
df = pd.read_csv('data/Auto.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# 5    15.0          8         429.0        198    4341          10.0    70
# 6    14.0          8         454.0        220    4354           9.0    70
# 7    14.0          8         440.0        215    4312           8.5    70
# 8    14.0          8         455.0        225    4425          10.0    70
# 9    15.0          8         390.0        190    3850           8.5    70
# 10   15.0          8         383.0        170    3563          10.0    70
# 11   14.0          8         340.0        160    3609           8.0    70
# ...

# %%
#removing missing values
df = df.dropna()

# %% [markdown]
# <h3>Which of the predictors are quantitative, and which are qualitative?</h3>
#
# <h4>Quantitative predictors:mpg,cylinders,displacement,horsepower,weight,acceleration</h4>
#
# <h4>Qualitative predictors:origin,name,year</h4>

# %% [markdown]
# <h4>What is the range of each quantitative predictor?</h4>
# <h4>What is the mean and standard deviation of each quantitative predictor?</h4>

# %%
quantitative_preds = df[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']]
quantitative_preds.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year
# count  397.000000
# mean    75.994962
# std      3.690005
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %% [markdown]
# <h3>Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?</h3>

# %%
subset = quantitative_preds[9:84]
subset.describe()
# Out:
#              mpg  cylinders  displacement       weight  acceleration  \
# count  75.000000  75.000000     75.000000    75.000000     75.000000
# mean   19.520000   5.853333    222.566667  3137.226667     14.826667
# std     6.103521   1.857733    119.215860   980.514558      2.954032
# min     9.000000   3.000000     70.000000  1613.000000      8.000000
# 25%    14.000000   4.000000    111.500000  2259.000000     13.000000
# 50%    19.000000   6.000000    200.000000  2933.000000     14.500000
# 75%    25.000000   8.000000    329.000000  4113.500000     16.250000
# max    35.000000   8.000000    455.000000  5140.000000     23.500000
#
#             year
# count  75.000000
# mean   71.093333
# std     0.791395
# min    70.000000
# 25%    70.000000
# 50%    71.000000
# 75%    72.000000
# max    72.000000

# %% [markdown]
# <h3>Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your ﬁndings.</h3>

# %%
quantitative_preds.plot(kind='scatter', x='cylinders', y='mpg', color='r')

# %%
quantitative_preds.plot(kind='scatter', x='displacement', y='mpg', color='g')

# %%
quantitative_preds.plot(kind='scatter', x='weight', y='mpg', color='b')

# %%
quantitative_preds.plot(kind='scatter', x='acceleration', y='mpg', color='y')

# %%
quantitative_preds.plot(kind='scatter', x='cylinders', y='displacement', color='r')

# %%
quantitative_preds.plot(kind='scatter', x='cylinders', y='weight', color='r')

# %%
quantitative_preds.plot(kind='scatter', x='cylinders', y='acceleration', color='r')

# %%
quantitative_preds.plot(kind='scatter', x='weight', y='displacement', color='r')

# %%
quantitative_preds.plot(kind='scatter', x='acceleration', y='displacement', color='r')

# %% [raw]
# Inferences: Displacement and weight has a negative impact on mpg
#             Acceleration has a positive impact on mpg
#             Weight has a positive impact on displacement
#             Displacement and weight are multi-collinear

# %%
#plotting boxplots for qualitative predictors
df.plot(kind='box', x='origin', y='mpg', color='r')

# %%
df.plot(kind='box', x='year', y='mpg', color='r')

# %%
df.plot(kind='box', x='year', y='displacement', color='r')

# %% [markdown]
# <h3>Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.</h3>

# %% [raw]
# The following 3 predictors can be used to predict mpg: weight, displacement, acceleration
